# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.1+cu126 CUDA:0 (Tesla T4, 14931MiB)
# Setup complete ✅ (8 CPUs, 29.4 GB RAM, 48.7/368.0 GB disk)

# %%
from ultralytics import YOLO

# %%
# %pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="R0gtDCiJCUQAHuMLAoVW")
project = rf.workspace("spectrogramyolo").project("yolobioacoustics")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model = YOLO("yolo11m.pt")
results = model.tune(
    data="/teamspace/studios/this_studio/YOLOBioacoustics-10/data.yaml",
    epochs=50,
    imgsz=640,
    iterations=12,
    resume=True,
    name='/teamspace/studios/this_studio/runs/detect/tunem'
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=/teamspace/studios/this_studio/runs/detect/tunem'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Resuming tuning run /teamspace/studios/this_studio/runs/detect/tunem from iteration 7...
# Tuner: Starting iteration 7/12 with hyperparameters: {'lr0': 0.00998, 'lrf': 0.01192, 'momentum': 0.91569, 'weight_decay': 0.00055, 'warmup_epochs': 2.38813, 'warmup_momentum': 0.68105, 'box': 8.13756, 'cls': 0.48311, 'dfl': 1.65504, 'hsv_h': 0.015, 'hsv_s': 0.7193, 'hsv_v': 0.41843, 'degrees': 0.0, 'translate': 0.09673, 'scale': 0.59649, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.45031, 'bgr': 0.0, 'mosaic': 0.99644, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.3.165 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.1+cu126 CUDA:0 (Tesla T4, 14931MiB)
# ...

# %%
model = YOLO("yolo11s.pt")
results = model.tune(
    data="/teamspace/studios/this_studio/YOLOBioacoustics-10/data.yaml",
    epochs=30,
    imgsz=640,
    iterations=30,
    resume=True,
    name='/teamspace/studios/this_studio/runs/detect/tune'
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=/teamspace/studios/this_studio/runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Resuming tuning run /teamspace/studios/this_studio/runs/detect/tune from iteration 4...
# Tuner: Starting iteration 4/30 with hyperparameters: {'lr0': 0.01038, 'lrf': 0.00831, 'momentum': 0.92363, 'weight_decay': 0.00051, 'warmup_epochs': 3.3317, 'warmup_momentum': 0.80164, 'box': 6.26445, 'cls': 0.48312, 'dfl': 1.25367, 'hsv_h': 0.01189, 'hsv_s': 0.77447, 'hsv_v': 0.30172, 'degrees': 0.0, 'translate': 0.08514, 'scale': 0.40485, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.52931, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.3.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.162 🚀 Python-3.10.10 torch-2.7.1+cu126 CUDA:0 (Tesla T4, 14931MiB)
# ...
